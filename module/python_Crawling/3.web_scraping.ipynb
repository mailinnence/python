# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup

import pyautogui as pg
import clipboard
import cv2

import time
import requests

# %%
driver = webdriver.Chrome(ChromeDriverManager().install()) 
driver.get('https://www.naver.com/')
driver.implicitly_wait(5)
driver.maximize_window()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 107.0.5304
# Get LATEST chromedriver version for 107.0.5304 google-chrome
# Driver [C:\Users\maili\.wdm\drivers\chromedriver\win32\107.0.5304.62\chromedriver.exe] found in cache
# C:\Users\maili\AppData\Local\Temp\ipykernel_2668\3193770458.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver.find_element(By.CSS_SELECTOR,'#query').send_keys("아이유")

# %%
driver.find_element(By.CSS_SELECTOR,'#search_btn > span.ico_search_submit').click()

# %%
driver.find_element(By.CSS_SELECTOR,'#lnb > div.lnb_group > div > ul > li:nth-child(3) > a').click()

# %%
#realTimeRankFavorite > li.rank01 > a
#realTimeRankFavorite > li.rank02 > a
#realTimeRankFavorite > li.rank03 > a

# 규칙이 보인다.

# %%
# for i in range(10):
#     i+=1
#     driver.find_element(By.CSS_SELECTOR,'#realTimeRankFavorite > li.rank0{} > a'.format(i)).click()
    
driver.get('https://comic.naver.com/webtoon/weekday')    
for i in range(1,11):
    i = format(i,'02')
    title = driver.find_element(By.CSS_SELECTOR,'#realTimeRankFavorite > li.rank{} > a'.format(i))    
    print(i,"위 :",title.text)
# Out:
# 01 위 : 김부장-54화 충격의 도가니
# 02 위 : 내가 키운 S급들-55화 : 대화(2)
# 03 위 : 여신강림-외전-9화[수진ep]
# 04 위 : 마루는 강쥐-22화. 너도 누구에게
# 05 위 : 멸망 이후의 세계-제 40 화
# 06 위 : 중증외상센터 : 골든 아워-외전 3화 : 미친 인턴 (3)
# 07 위 : 대학원 탈출일지-72화-돌아온 세미나(2)
# 08 위 : 놓지마 정신줄 시즌3-1001화 돌아온정신 1
# 09 위 : 1을 줄게-번외편 1화
# 10 위 : 랜덤채팅의 그녀!-257. 경고

# %%
# for i in range(10):
#     i+=1
#     driver.find_element(By.CSS_SELECTOR,'#realTimeRankFavorite > li.rank0{} > a'.format(i)).click()
    
driver.get('https://comic.naver.com/webtoon/weekday')
driver.find_element(By.CSS_SELECTOR,'#realTimeRankChoiceTabUpdateClick > img').click()

driver.implicitly_wait(5)
for i in range(1,11):
    i = format(i,'02')
    title = driver.find_element(By.CSS_SELECTOR,'#realTimeRankUpdate > li.rank{} > a'.format(i))    
    print(i,"위 :",title.text)
# Out:
# 01 위 : 올가미-150화
# 02 위 : 이븐 모어-53화
# 03 위 : 택배 왔습니다-마지막 화
# 04 위 : 그 남주와 이별하는 방법-47화. 왕의 후계자(3)
# 05 위 : 테러사이트-6화 : 모순
# 06 위 : 삼국지톡-입촉_40.성도공략전 (3) "패왕이 되소서!"
# 07 위 : 제로게임-[313] 재가 되어
# 08 위 : 랜덤채팅의 그녀!-257. 경고
# 09 위 : 여신강림-외전-9화[수진ep]
# 10 위 : 찐:종합게임동아리-82화

# %%
    
driver.get('https://product.kyobobook.co.kr/bestseller/online?period=001')

driver.implicitly_wait(5)
titles = driver.find_elements(By.CSS_SELECTOR, "span.prod_name")

# %%
for i in range(len(titles)):
    print(titles[i].text)
# Out:
# 조국의 법고전 산책
# 트렌드 코리아 2023
# 아버지의 해방일지
# 이은경쌤의 초등어휘일력 365
# 하얼빈
# 불편한 편의점(40만부 기념 벚꽃 에디션)
# 불편한 편의점 2(단풍 에디션)
# 나 혼자만 알고 싶은 실전 심리학
# 조금 서툴더라도 네 인생을 응원해
# 역행자
# 인생의 허무를 어떻게 할 것인가
# 나의 월급 독립 프로젝트(리마스터 에디션)
# 마흔에 읽는 니체
# 조셉 머피 부의 초월자
# 다이어트 사이언스(2022)
# 세상에서 가장 쉬운 본질육아
# 잘될 수밖에 없는 너에게
# 마법천자문 55: 분명하게 정해라! 결정
# 우리, 편하게 말해요
# 데일 카네기 인간관계론

# %%
for title in titles:
    print(title.text)
# Out:
# 조국의 법고전 산책
# 트렌드 코리아 2023
# 아버지의 해방일지
# 이은경쌤의 초등어휘일력 365
# 하얼빈
# 불편한 편의점(40만부 기념 벚꽃 에디션)
# 불편한 편의점 2(단풍 에디션)
# 나 혼자만 알고 싶은 실전 심리학
# 조금 서툴더라도 네 인생을 응원해
# 역행자
# 인생의 허무를 어떻게 할 것인가
# 나의 월급 독립 프로젝트(리마스터 에디션)
# 마흔에 읽는 니체
# 조셉 머피 부의 초월자
# 다이어트 사이언스(2022)
# 세상에서 가장 쉬운 본질육아
# 잘될 수밖에 없는 너에게
# 마법천자문 55: 분명하게 정해라! 결정
# 우리, 편하게 말해요
# 데일 카네기 인간관계론

# %%
# for i in range(10):
#     i+=1
#     driver.find_element(By.CSS_SELECTOR,'#realTimeRankFavorite > li.rank0{} > a'.format(i)).click()
    
driver.get('https://comic.naver.com/webtoon/weekday')
driver.find_element(By.CSS_SELECTOR,'#realTimeRankChoiceTabUpdateClick > img').click()

driver.implicitly_wait(5)
for i in range(1,11):
    i = format(i,'02')
    title = driver.find_element(By.CSS_SELECTOR,'#realTimeRankUpdate > li.rank{} > a'.format(i))    
    print(i,"위 :",title.text)
# Out:
# 01 위 : 올가미-150화
# 02 위 : 이븐 모어-53화
# 03 위 : 택배 왔습니다-마지막 화
# 04 위 : 그 남주와 이별하는 방법-47화. 왕의 후계자(3)
# 05 위 : 테러사이트-6화 : 모순
# 06 위 : 삼국지톡-입촉_40.성도공략전 (3) "패왕이 되소서!"
# 07 위 : 제로게임-[313] 재가 되어
# 08 위 : 랜덤채팅의 그녀!-257. 경고
# 09 위 : 여신강림-외전-9화[수진ep]
# 10 위 : 찐:종합게임동아리-82화

# %%
# for i in range(10):
#     i+=1
#     driver.find_element(By.CSS_SELECTOR,'#realTimeRankFavorite > li.rank0{} > a'.format(i)).click()
    
driver.get('https://comic.naver.com/index')

driver.implicitly_wait(5)
titles = driver.find_elements(By.CSS_SELECTOR,'#realTimeRankFavorite > li > a')    
for title in titles:
    print(title.text)
# Out:
# 김부장-54화 충격의 도가니
# 내가 키운 S급들-55화 : 대화(2)
# 여신강림-외전-9화[수진ep]
# 마루는 강쥐-22화. 너도 누구에게
# 멸망 이후의 세계-제 40 화
# 중증외상센터 : 골든 아워-외전 3화 : 미친 인턴 (3)
# 대학원 탈출일지-72화-돌아온 세미나(2)
# 놓지마 정신줄 시즌3-1001화 돌아온정신 1
# 1을 줄게-번외편 1화
# 랜덤채팅의 그녀!-257. 경고

# %%
# for i in range(10):
#     i+=1
#     driver.find_element(By.CSS_SELECTOR,'#realTimeRankFavorite > li.rank0{} > a'.format(i)).click()
    
driver.get('https://comic.naver.com/webtoon/weekday')
driver.find_element(By.CSS_SELECTOR,'#realTimeRankChoiceTabUpdateClick > img').click()
driver.implicitly_wait(5)

titles = driver.find_elements(By.CSS_SELECTOR,'#realTimeRankUpdate > li > a')    
for title in titles:
    print(title.text)
# Out:
# 올가미-150화
# 이븐 모어-53화
# 택배 왔습니다-마지막 화
# 그 남주와 이별하는 방법-47화. 왕의 후계자(3)
# 테러사이트-6화 : 모순
# 삼국지톡-입촉_40.성도공략전 (3) "패왕이 되소서!"
# 제로게임-[313] 재가 되어
# 랜덤채팅의 그녀!-257. 경고
# 여신강림-외전-9화[수진ep]
# 찐:종합게임동아리-82화

# %%
driver = webdriver.Chrome(ChromeDriverManager().install()) 
driver.get('https://www.naver.com/')
driver.implicitly_wait(5)
driver.maximize_window()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 107.0.5304
# Get LATEST chromedriver version for 107.0.5304 google-chrome
# Driver [C:\Users\maili\.wdm\drivers\chromedriver\win32\107.0.5304.62\chromedriver.exe] found in cache
# C:\Users\maili\AppData\Local\Temp\ipykernel_7304\3193770458.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
titles = driver.find_elements(By.CSS_SELECTOR,'.list_nav.NM_FAVORITE_LIST > li')
for title in titles:
    print(title.text)
# Out:
# 사전
# 뉴스
# 증권
# 부동산
# 지도
# VIBE
# 도서
# 웹툰

# %%
html_src = driver.page_source
soup = BeautifulSoup(html_src , "html.parser")

# %%
soup
# Out:
# <html data-dark="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36" lang="ko"><head><script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-core.js" type="text/javascript"></script> <meta charset="utf-8"/> <title>NAVER</title> <meta content="IE=edge" http-equiv="X-UA-Compatible"/> <meta content="width=1190" name="viewport"/> <meta content="NAVER" name="apple-mobile-web-app-title"/> <meta content="index,nofollow" name="robots"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"/> <meta content="네이버" property="og:title"/> <meta content="https://www.naver.com/" property="og:url"/> <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/> <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"/> <meta content="summary" name="twitter:card"/> <meta content="" name="twitter:title"/> <meta content
# ...

# %%
driver.get('https://comic.naver.com/webtoon/weekday')
driver.find_element(By.CSS_SELECTOR,'#realTimeRankChoiceTabUpdateClick > img').click()
driver.implicitly_wait(5)

# %%
html_src = driver.page_source
soup = BeautifulSoup(html_src , "html.parser")
titles = soup.select("#realTimeRankFavorite > li > a")
titles[0].text
# Out:
# '김부장-54화 충격의 도가니'

# %%
for title in titles:
    print(title.text)
# Out:
# 김부장-54화 충격의 도가니
# 내가 키운 S급들-55화 : 대화(2)
# 여신강림-외전-9화[수진ep]
# 마루는 강쥐-22화. 너도 누구에게
# 놓지마 정신줄 시즌3-1001화 돌아온정신 1
# 멸망 이후의 세계-제 40 화
# 중증외상센터 : 골든 아워-외전 3화 : 미친 인턴 (3)
# 하루만 네가 되고 싶어-132. 살 길
# 1을 줄게-번외편 1화
# 대학원 탈출일지-72화-돌아온 세미나(2)

# %%
driver.get('https://finance.naver.com/')
driver.implicitly_wait(5)

# %%
html_src = driver.page_source
html_src
# Out:
# '<html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36"><head> \n  <title>네이버 금융</title> \n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8"> \n  <meta http-equiv="Content-Script-Type" content="text/javascript"> \n  <meta http-equiv="Content-Style-Type" content="text/css"> \n  <meta name="apple-mobile-web-app-title" content="네이버 금융"> \n  <meta property="og:title" content="네이버 금융"> \n  <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"> \n  <meta property="og:url" content="https://finance.naver.com"> \n  <meta property="og:description" content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공"> \n  <meta property="og:type" content="article"> \n  <meta property="og:article:thumbnailUrl" content=""> \n  <meta property="og:article:author" content="네이버금융"> \n  <meta property="og:article:author:url" content="http://FINANCE.NAVER.COM"> \n  <link
# ...

# %%
soap =  BeautifulSoup(html_src, "html.parser")
soap
# Out:
# <html data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36" lang="ko"><head>
# <title>네이버 금융</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버 금융" name="apple-mobile-web-app-title"/>
# <meta content="네이버 금융" property="og:title"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="https://finance.naver.com" property="og:url"/>
# <meta content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버금융" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# ...

# %%
soup = BeautifulSoup(html_src , "html.parser")
titles = soup.select(".section_strategy li a")
for title in titles:
    print(title.text)
# Out:
# [Asia오전]'제로 코로나' 혼란에 中·홍콩 약세
# [오전시황] 기관 매수세에 코스피 2380선…삼전·하이닉스 강세
# [굿모닝 증시]중간선거 앞두고 오른 美 증시에 원화 강세까지…"코스피 상승 출발할 것"
# 환율, 1390원대 하락 안착 예상…달러 약세+위안 강세[외환브리핑]
# 중간선거 '기대감'에 증시UP...'감원' 메타 6%↑[뉴욕마감](종합)
# 미 중간선거 막 올라…뉴욕증시, 美중간선거 앞두고 상승[모닝브리핑]

# %%
soup = BeautifulSoup(html_src , "html.parser")
titles = soup.select(".section_strategy > ul a")
for title in titles:
    print(title.text)
# Out:
# [Asia오전]'제로 코로나' 혼란에 中·홍콩 약세
# [오전시황] 기관 매수세에 코스피 2380선…삼전·하이닉스 강세
# [굿모닝 증시]중간선거 앞두고 오른 美 증시에 원화 강세까지…"코스피 상승 출발할 것"
# 환율, 1390원대 하락 안착 예상…달러 약세+위안 강세[외환브리핑]
# 중간선거 '기대감'에 증시UP...'감원' 메타 6%↑[뉴욕마감](종합)
# 미 중간선거 막 올라…뉴욕증시, 美중간선거 앞두고 상승[모닝브리핑]

# %%
driver = webdriver.Chrome(ChromeDriverManager().install()) 
driver.get('https://product.kyobobook.co.kr/bestseller/total?period=003')
driver.implicitly_wait(5)
driver.maximize_window()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 107.0.5304
# Get LATEST chromedriver version for 107.0.5304 google-chrome
# Driver [C:\Users\maili\.wdm\drivers\chromedriver\win32\107.0.5304.62\chromedriver.exe] found in cache
# C:\Users\maili\AppData\Local\Temp\ipykernel_7304\3703280474.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
html_src = driver.page_source
html_src
# Out:
# '<html lang="ko" data-view="ink" class="kbb_loaded"><head>\n    <meta name="google-site-verification" content="2dlgBOp3K0s6wHjZo_Hkas6yaYPKZIVsmres9vC3F34">\n    \n        \n        \n<meta charset="UTF-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1">\n\n\n\n\n\n    <meta name="title" content=" 종합 월간 베스트셀러 - 교보문고">\n    <meta name="description" content="교보문고 종합베스트셀러 페이지에서는 온라인과 매장에서 주문된 도서, 전자책의 월간 판매량을 집계하여 소개합니다.">\n    \n    <meta property="og:title" content=" 종합 월간 베스트셀러 - 교보문고">\n    <meta property="og:type" content="website">\n    <meta property="og:image" content="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo@2x.png">\n    <meta property="og:url" content="https://product.kyobobook.co.kr/bestseller/total?periodUri=003">\n    <meta property="og:description" content="교보문고 종합베스트셀러 페이지에서는 온라인과 매장에서 주문된 도서, 전자책의 월간 판매량을 집계하여 소개합니다.">\n\n 
# ...

# %%
soup = BeautifulSoup(html_src , "html.parser")
soup
# Out:
# <html class="kbb_loaded" data-view="ink" lang="ko"><head>
# <meta content="2dlgBOp3K0s6wHjZo_Hkas6yaYPKZIVsmres9vC3F34" name="google-site-verification"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" name="viewport"/>
# <meta content=" 종합 월간 베스트셀러 - 교보문고" name="title"/>
# <meta content="교보문고 종합베스트셀러 페이지에서는 온라인과 매장에서 주문된 도서, 전자책의 월간 판매량을 집계하여 소개합니다." name="description"/>
# <meta content=" 종합 월간 베스트셀러 - 교보문고" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://contents.kyobobook.co.kr/resources/fo/images/common/ink/img_logo_kyobo@2x.png" property="og:image"/>
# <meta content="https://product.kyobobook.co.kr/bestseller/total?periodUri=003" property="og:url"/>
# <meta content="교보문고 종합베스트셀러 페이지에서는 온라인과 매장에서 주문된 도서, 전자책의 월간 판매량을 집계하여 소개합니다." property="og:description"/>
# ...

# %%
titles = soup.select(".section_strategy > ul a")
for title in titles:
    print(title.text)

# %%
driver = webdriver.Chrome(ChromeDriverManager().install()) 
driver.get('https://terms.naver.com/list.naver?cid=67995&categoryId=67995')
driver.implicitly_wait(5)
driver.maximize_window()

html_src = driver.page_source
soup = BeautifulSoup(html_src , "html.parser")
titles = soup.select(".content_list .title > a:nth-child(1)")

for title in titles:
    print(title.text)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 107.0.5304
# Get LATEST chromedriver version for 107.0.5304 google-chrome
# Driver [C:\Users\maili\.wdm\drivers\chromedriver\win32\107.0.5304.62\chromedriver.exe] found in cache
# C:\Users\maili\AppData\Local\Temp\ipykernel_2668\356989036.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# 재고회전율
# 자위소방대
# 옥내소화전설비 [Open Loop]
# 접지 [Grounding]
# 선재 [wire rods]
# 전기아연도금강판 [electrolytic galvanized iron]
# 슬리터 [slitter]
# 후판 [plate]
# 앵글 [angle]
# 핀홀 [pin hole]
# 복공판
# 연결살수설비
# 납사 [naphtha]
# 물질안전보건자료 [Material Safety Data Sheet]
# 공정 [共晶, eutectic]
